# %%
import pandas as pd 

pd.DataFrame(data = [['import xgboost as xgb', 'from xgboost import XGBClassifier'],
                     ['DMatrix 객체 별도 생성\ntrain = xgb.DMatrix(data = X_train, label = y_train)', '넘파이나 판다스 이용'],
                     ['Xgb_model = xgb.train()\nXgb_model은 학습된 객체를 반환받음', 'XGBClassifier.fit()'],
                     ['xgb.train()으로 학습된 객체에서 predict()호출, 이 때는 예측 결과가 아닌 예측 결과를 추정하는 확률값 반환', 'XGBCLassifier.predict(), 예측 결과값 반환'],
                     ['plot_importance()함수 이용', 'plot_importance()함수 이용']], columns = ['파이썬 Wrapper', '사이킷런 Wrapper'],\
                     index = ['사용 모듈', '학습용과 테스트용 데이터 세트',' 학습 API', '예측 API', '피처 중요도 시각화'])
# Out:
#                                                         파이썬 Wrapper  \
# 사용 모듈                                         import xgboost as xgb
# 학습용과 테스트용 데이터 세트  DMatrix 객체 별도 생성\ntrain = xgb.DMatrix(data = X...
#  학습 API            Xgb_model = xgb.train()\nXgb_model은 학습된 객체를 반환받음
# 예측 API            xgb.train()으로 학습된 객체에서 predict()호출, 이 때는 예측 결과...
# 피처 중요도 시각화                                   plot_importance()함수 이용
#
#                                         사이킷런 Wrapper
# 사용 모듈              from xgboost import XGBClassifier
# 학습용과 테스트용 데이터 세트                         넘파이나 판다스 이용
#  학습 API                          XGBClassifier.fit()
# 예측 API            XGBCLassifier.predict(), 예측 결과값 반환
# 피처 중요도 시각화                    plot_importance()함수 이용

# %%
pd.DataFrame(data = [['eta', 'learning_rate', '학습률 파라미터, 0에서 1사이의 값을 지정하여 스텝을 수행할 때 업데이트되는 학습률 파이썬 래퍼 디폴트는 0.3, 사이킷런은 0.1'],
                     ['num_boost_rounds', 'n_estimators,' '사이킷런 앙상블의 n_estimators와 동일'],
                     ['min_child_weight', 'min_child_weight', '결정 트리의 min_child_leaf와 유사하며 과적합 조절용'],
                     ['max_depth', 'max_depth', '결정 트리의 max_depth와 동일'], 
                     ['sub_sample' ,'sumsample', 'GBM의 sumsample와 동일. 일반적으로 0.5~1 사이의 값을 가진다']],\
             columns = ['파이썬 Wrapper', '사이킷런 Wrapper', '하이퍼 파라미터 설명'],\
             index = ['','','','',''])
# Out:
#        파이썬 Wrapper                             사이킷런 Wrapper  \
#                eta                            learning_rate
#   num_boost_rounds  n_estimators,사이킷런 앙상블의 n_estimators와 동일
#   min_child_weight                         min_child_weight
#          max_depth                                max_depth
#         sub_sample                                sumsample
#
#                                         하이퍼 파라미터 설명
#   학습률 파라미터, 0에서 1사이의 값을 지정하여 스텝을 수행할 때 업데이트되는 학습...
#                                                None
#                 결정 트리의 min_child_leaf와 유사하며 과적합 조절용
#                                결정 트리의 max_depth와 동일
#          GBM의 sumsample와 동일. 일반적으로 0.5~1 사이의 값을 가진다
